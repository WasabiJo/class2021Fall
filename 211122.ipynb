# %% [markdown]
# <a href="https://colab.research.google.com/github/WasabiJo/class2021Fall/blob/main/211122.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import IPython.display as ipd

# %%
def phasor_sine(amp, sr, dur, freq, phase):
  t = np.arange(1, sr * dur+1)/sr
  theta = t * 2*np.pi * freq + phase
  s = amp * np.sin(theta)
  return s, t, theta

# %%
amp = 1; sr = 10000; phase = 0

C = 523.25
Db = 554.37
D = 587.33
Eb = 622.25
E = 659.25
F = 698.46
Gb = 739.99
G = 783.99
Ab = 830.61
A = 880.00
Bb = 932.33
B = 987.77

# %%
#Shiroi Parasol - Matusda Seiko

notes = [Gb, 0, Gb, 0, E, 0, E, 0, Gb, 0, Eb, 0, Eb, 0, Gb, 0, Db, 0, Db, 0, Eb, 0, Db, 0, Eb, 0, Db, 0, B/2, 0, B/2, \
         Gb, 0, Gb, 0, E, 0, E, 0, Gb, 0, Eb, 0, Eb, 0, Gb, 0, Ab, 0, Bb, 0, Eb, 0, Db, 0, B/2, \
         Gb, Eb, Ab, Gb, B/2, Gb, Eb, Ab, Gb, Bb, Gb, Eb, Ab, Gb, Gb, Gb, Ab, A, \
         Ab, E, Gb, E, Gb, E, B, E, E, Eb, Eb]
        
durs = [0.25, 0.05, 0.25, 0.05, 0.5, 0.05, 0.5, 0.05, 0.25, 0.05, 0.25, 0.4, 0.25, 0.05, 0.5, 0.4, 0.25, 0.05, 0.25, 0.05, 0.4, 0.05, 0.4, \
      0.05, 0.30, 0.05, 0.30, 0.05, 0.30, 0.05, 0.4, 0.4, 0.25, 0.05, 0.25, 0.05, 0.5, 0.05, 0.5, 0.05, 0.25, 0.05, 0.25, 0.50, 0.25, 0.05, 0.5, \
        0.5, 0.4, 1.0, 0.05, 0.25, 0.05, 0.25, 0.05, 0.5, \
        0.3, 0.3, 0.3, 0.25, 1, 0.3, 0.3, 0.3, 0.25, 1, 0.3, 0.3, 0.25, 0.4, \
        0.4, 0.25, 0.25, 0.25, 1, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, \
        0.3, 0.3, 0.3]
len(notes)
# Out:
# 85

# %%
s_all = np.empty(0)

for note, dur in zip(notes, durs):
  s, t, th= phasor_sine(amp, sr, dur, note, phase)
  s_all = np.concatenate((s_all, s))

# %%
ipd.Audio(s_all, rate=sr)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
